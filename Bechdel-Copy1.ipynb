# %%
import pickle
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1 : Listing Movies to Query

# %%
movies = pd.read_csv('data/tmdb_5000_movies.csv')
movies.drop(['homepage', 'keywords','original_language','overview','release_date','spoken_languages', \
             'status','title','tagline','vote_count'\
            ], \
            axis=1, \
            inplace=True \
           )

# %%
credits = pd.read_csv('data/tmdb_5000_credits.csv')
credits = credits[credits.cast != '[]']
credits.drop(['title', 'crew'], axis=1, inplace=True)
credits['cast_id'] = credits['cast'].apply(lambda row: list(set(pd.read_json(row)['id'])))

# %%
frames = pd.DataFrame()
new_df = pd.DataFrame()

for idx, film in credits.iterrows():
    cast_df = pd.DataFrame(eval(credits['cast'][idx]))
    cast_df['credits'] = idx
    cast_df = cast_df.drop(['character','order', 'credit_id', 'cast_id'],axis = 1)  
    
    frames = [new_df, cast_df]
    new_df = pd.concat(frames, join = 'outer', ignore_index=True)

# %%
discount_old = credits['cast_id'].apply(pd.Series).stack().value_counts()
discount_old = list(discount_old[discount_old > 4].index.astype(int))

# %%
nodes_df = new_df['credits'].groupby([new_df.gender, new_df.id, new_df.name]).apply(list).reset_index()
nodes_df = nodes_df[nodes_df['gender'].isin(['1','2'])]
discount_1 = nodes_df['id'].tolist()
discount = [x for x in discount_old if x in discount_1]

# %%
credits['cast_id'] = credits['cast_id'].apply(lambda x: [y for y in x if y in discount])
credits['edges'] = credits['cast_id'].apply(lambda x: list(itertools.combinations(x, 2)))

# %%
discarded_movies = set()

for idx, movie in credits.iterrows():
    if len(movie['edges']) == 0:
        discarded_movies.add(movie['movie_id'])

print(len(discarded_movies))
# Out:
# 663

# %%
movies = movies[~movies['id'].isin(discarded_movies)]
movies['bechdel'] = ''
movies.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
# 2                                   Spectre  107.376788
# 3                     The Dark Knight Rises  112.312950
# 4                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries     revenue  runtime  \
# 0  [{"iso_3166_1": "US", "name": "United States o...  2787965087    162.0
# 1  [{"iso_3166_1": "US", "name": "United States o...   961000000    169.0
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   880674609    148.0
# 3  [{"iso_3166_1": "US", "name": "United States o...  1084939099    165.0
# 4  [{"iso_3166_1": "US", "name": "United States o...   284139100    132.0
#
#    vote_average bechdel
# 0           7.2
# 1           6.9
# 2           6.3
# 3           7.6
# 4           6.1

# %%
with open('data/bechdel.pkl', 'rb') as pkl_file: 
    movies_bechdel = pickle.load(pkl_file)
    
movies_bechdel.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
# 2                                   Spectre  107.376788
# 3                     The Dark Knight Rises  112.312950
# 4                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries     revenue  runtime  \
# 0  [{"iso_3166_1": "US", "name": "United States o...  2787965087    162.0
# 1  [{"iso_3166_1": "US", "name": "United States o...   961000000    169.0
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   880674609    148.0
# 3  [{"iso_3166_1": "US", "name": "United States o...  1084939099    165.0
# 4  [{"iso_3166_1": "US", "name": "United States o...   284139100    132.0
#
#    vote_average  bechdel
# 0           7.2      0.0
# 1           6.9      1.0
# 2           6.3      0.0
# 3           7.6      0.0
# 4           6.1      1.0

# %%
movies_bechdel['bechdel'] = movies_bechdel['bechdel'].map({-1:-1, '0':0, '1':0, '2':0, '3':1, ' ':0})
movies_bechdel['bechdel'].value_counts()
# Out:
# -1.0    1646
#  1.0    1358
#  0.0    1130
# Name: bechdel, dtype: int64

# %%
movies_bechdel.corr()
# Out:
#                 budget        id  popularity   revenue   runtime  \
# budget        1.000000 -0.055604    0.489507  0.723982  0.279442
# id           -0.055604  1.000000    0.090769 -0.020148 -0.133421
# popularity    0.489507  0.090769    1.000000  0.636844  0.229755
# revenue       0.723982 -0.020148    0.636844  1.000000  0.264570
# runtime       0.279442 -0.133421    0.229755  0.264570  1.000000
# vote_average  0.087631 -0.185161    0.292053  0.220390  0.402501
# bechdel       0.202766 -0.020614    0.292492  0.266546  0.156131
#
#               vote_average   bechdel
# budget            0.087631  0.202766
# id               -0.185161 -0.020614
# popularity        0.292053  0.292492
# revenue           0.220390  0.266546
# runtime           0.402501  0.156131
# vote_average      1.000000  0.288393
# bechdel           0.288393  1.000000

# %%
movies_bechdel[(movies_bechdel['revenue'] != 0) & (movies_bechdel['budget'] != 0) & (movies_bechdel['bechdel'] != -1)].count()
# Out:
# budget                  2117
# genres                  2117
# id                      2117
# original_title          2117
# popularity              2117
# production_companies    2117
# production_countries    2117
# revenue                 2117
# runtime                 2117
# vote_average            2117
# bechdel                 2117
# dtype: int64

# %%
movies_bechdel[(movies_bechdel['bechdel'] == 1) & ]
# Out:
#          budget                                             genres      id  \
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...   38757
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   99861
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     767
# 14    225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49521
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...    2454
# 21    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   20662
# 22    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...   57158
# 23    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    2268
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...     597
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...  271110
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  135397
# 29    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   37724
# 31    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   68721
# 32    200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...   12155
# 33    210000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...   36668
# 35    150000000  [{"id": 878, "name": "Science Fiction"}, {"id"...    8373
# 36    210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...   91314
# 37    200000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...   68728
# 42    200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...   10193
# 44    190000000                     [{"id": 28, "name": "Action"}]  168259
# 45    200000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...   72190
# 49    105000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   64682
# 52    195000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...   38356
# 54    175000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...  105864
# 55    185000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...   62177
# 61    176000003  [{"id": 878, "name": "Science Fiction"}, {"id"...   76757
# 63    180000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...     411
# 64    178000000           [{"id": 878, "name": "Science Fiction"}]  246655
# ...         ...                                                ...     ...
# 4454          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   11446
# 4455     800000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   47889
# 4470     750000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   84332
# 4472     500000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...   74725
# 4473     750000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...   58428
# 4485     700000                      [{"id": 18, "name": "Drama"}]    7859
# 4516     500000  [{"id": 27, "name": "Horror"}, {"id": 878, "na...   30315
# 4518     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...    2056
# 4533          0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...  172533
# 4539     500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   45649
# 4576          0  [{"id": 80, "name": "Crime"}, {"id": 53, "name...  188166
# 4586   35000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...    9029
# 4604     325000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...    3078
# 4609          0                     [{"id": 35, "name": "Comedy"}]   11956
# 4610     300000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...    1550
# 4613     200000                      [{"id": 18, "name": "Drama"}]    8942
# 4616          0                [{"id": 99, "name": "Documentary"}]   87943
# 4630          0  [{"id": 18, "name": "Drama"}, {"id": 53, "name...   84188
# 4631     250000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...    2255
# 4632     250000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   50035
# 4635          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...   29371
# 4639     250000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...     431
# 4640          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   76996
# 4643     250000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   60420
# 4650          0  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...   29917
# 4700     100000  [{"id": 18, "name": "Drama"}, {"id": 878, "nam...   55420
# 4715          0  [{"id": 878, "name": "Science Fiction"}, {"id"...   86812
# 4717     125000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...   84355
# 4744          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  244534
# 4752      65000  [{"id": 10749, "name": "Romance"}, {"id": 35, ...   47607
#
#                                          original_title  popularity  \
# 1              Pirates of the Caribbean: At World's End  139.082615
# 4                                           John Carter   43.926995
# 6                                               Tangled   48.681969
# 7                               Avengers: Age of Ultron  134.279229
# 8                Harry Potter and the Half-Blood Prince   98.885637
# 14                                         Man of Steel   99.398009
# 15             The Chronicles of Narnia: Prince Caspian   53.978602
# 21                                           Robin Hood   37.668301
# 22                  The Hobbit: The Desolation of Smaug   94.370564
# 23                                   The Golden Compass   42.990906
# 25                                              Titanic  100.025899
# 26                           Captain America: Civil War  198.372395
# 28                                       Jurassic World  418.708552
# 29                                              Skyfall   93.004993
# 31                                           Iron Man 3   77.682080
# 32                                  Alice in Wonderland   78.530105
# 33                                X-Men: The Last Stand    3.857526
# 35                  Transformers: Revenge of the Fallen   21.939663
# 36                      Transformers: Age of Extinction  116.840296
# 37                           Oz: The Great and Powerful   46.985445
# 42                                          Toy Story 3   59.995418
# 44                                            Furious 7  102.322217
# 45                                          World War Z   81.834855
# 49                                     The Great Gatsby   61.196071
# 52                       Transformers: Dark of the Moon   28.529607
# 54                                    The Good Dinosaur   51.692953
# 55                                                Brave  125.114374
# 61                                    Jupiter Ascending   85.369080
# 63    The Chronicles of Narnia: The Lion, the Witch ...   67.391328
# 64                                    X-Men: Apocalypse  139.272042
# ...                                                 ...         ...
# 4454                           Welcome to the Dollhouse    5.870319
# 4455                                   Ruby in Paradise    0.594240
# 4470                              Safety Not Guaranteed   25.186002
# 4472                                          Kill List   12.203041
# 4473                                     The Innkeepers   14.386807
# 4485                                        Half Nelson   12.378031
# 4516                             Kingdom of the Spiders    2.537032
# 4518                                  The Station Agent   11.578545
# 4533                                   Drinking Buddies   17.378455
# 4539                                             Rubber    9.108949
# 4576                                          Blue Ruin   25.349758
# 4586                              What Happens in Vegas   38.100488
# 4604                              It Happened One Night   11.871424
# 4609                            Chacun Cherche Son Chat    1.410387
# 4610                                    Pieces of April    4.270596
# 4613                                     Wendy and Lucy    0.713906
# 4616                                     Sisters in Law    0.025211
# 4630                                         Compliance    8.942203
# 4631                                        Chasing Amy   20.601483
# 4632                                   Lovely & Amazing    1.459170
# 4635  The Incredibly True Adventure of Two Girls In ...    1.708190
# 4639                                               Cube   44.656151
# 4640                        Love and Other Catastrophes    0.619348
# 4643                                         Like Crazy   21.825564
# 4650                                               Exam   20.265518
# 4700                                      Another Earth   25.402697
# 4715                                  Sound of My Voice    6.192383
# 4717                               Your Sister's Sister   12.833247
# 4744                                    Happy Christmas    7.052422
# 4752                                     Tiny Furniture    2.380332
#
#                                    production_companies  \
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# 6     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...
# 8     [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 14    [{"name": "Legendary Pictures", "id": 923}, {"...
# 15    [{"name": "Walt Disney", "id": 5888}, {"name":...
# 21    [{"name": "Imagine Entertainment", "id": 23}, ...
# 22    [{"name": "WingNut Films", "id": 11}, {"name":...
# 23    [{"name": "New Line Cinema", "id": 12}, {"name...
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 26    [{"name": "Studio Babelsberg", "id": 264}, {"n...
# 28    [{"name": "Universal Studios", "id": 13}, {"na...
# 29             [{"name": "Columbia Pictures", "id": 5}]
# 31              [{"name": "Marvel Studios", "id": 420}]
# 32    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 33    [{"name": "Ingenious Film Partners", "id": 289...
# 35    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 36    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 37    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 42    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 44    [{"name": "Universal Pictures", "id": 33}, {"n...
# 45    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 49    [{"name": "Village Roadshow Pictures", "id": 7...
# 52    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 54    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 55    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 61    [{"name": "Village Roadshow Pictures", "id": 7...
# 63    [{"name": "Walt Disney", "id": 5888}, {"name":...
# 64    [{"name": "Twentieth Century Fox Film Corporat...
# ...                                                 ...
# 4454                                                 []
# 4455  [{"name": "Ruby in Paradise", "id": 75712}, {"...
# 4470  [{"name": "Duplass Brothers Productions", "id"...
# 4472  [{"name": "Rook Films", "id": 16853}, {"name":...
# 4473  [{"name": "Glass Eye Pix", "id": 1360}, {"name...
# 4485  [{"name": "Thinkfilm", "id": 446}, {"name": "H...
# 4516  [{"name": "Arachnid Productions Ltd.", "id": 5...
# 4518  [{"name": "Next Wednesday Productions", "id": ...
# 4533  [{"name": "Burn Later Productions", "id": 18346}]
# 4539  [{"name": "Canal+", "id": 5358}, {"name": "Bac...
# 4576  [{"name": "Film Science", "id": 1976}, {"name"...
# 4586  [{"name": "Twentieth Century Fox Film Corporat...
# 4604  [{"name": "Columbia Pictures Corporation", "id...
# 4609  [{"name": "Vertigo Productions", "id": 2756}, ...
# 4610  [{"name": "Kalkaska Productions", "id": 728}, ...
# 4613  [{"name": "Glass Eye Pix", "id": 1360}, {"name...
# 4616             [{"name": "Vixen Films", "id": 82784}]
# 4630  [{"name": "Muskat Filmed Properties", "id": 10...
# 4631  [{"name": "Miramax Films", "id": 14}, {"name":...
# 4632                                                 []
# 4635                                                 []
# 4639  [{"name": "T\u00e9l\u00e9film Canada", "id": 8...
# 4640                                                 []
# 4643  [{"name": "Paramount Vantage", "id": 838}, {"n...
# 4650  [{"name": "Hazeldine Films", "id": 5004}, {"na...
# 4700    [{"name": "Artists Public Domain", "id": 8145}]
# 4715        [{"name": "Skyscraper Films", "id": 26197}]
# 4717                [{"name": "Ada Films", "id": 1424}]
# 4744  [{"name": "Lucky Coffee Productions", "id": 29...
# 4752             [{"name": "Tiny Ponies", "id": 65873}]
#
#                                    production_countries     revenue  runtime  \
# 1     [{"iso_3166_1": "US", "name": "United States o...   961000000    169.0
# 4     [{"iso_3166_1": "US", "name": "United States o...   284139100    132.0
# 6     [{"iso_3166_1": "US", "name": "United States o...   591794936    100.0
# 7     [{"iso_3166_1": "US", "name": "United States o...  1405403694    141.0
# 8     [{"iso_3166_1": "GB", "name": "United Kingdom"...   933959197    153.0
# 14    [{"iso_3166_1": "GB", "name": "United Kingdom"...   662845518    143.0
# 15    [{"iso_3166_1": "CZ", "name": "Czech Republic"...   419651413    150.0
# 21    [{"iso_3166_1": "GB", "name": "United Kingdom"...   310669540    140.0
# 22    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   958400000    161.0
# 23    [{"iso_3166_1": "GB", "name": "United Kingdom"...   372234864    113.0
# 25    [{"iso_3166_1": "US", "name": "United States o...  1845034188    194.0
# 26    [{"iso_3166_1": "US", "name": "United States o...  1153304495    147.0
# 28    [{"iso_3166_1": "US", "name": "United States o...  1513528810    124.0
# 29    [{"iso_3166_1": "GB", "name": "United Kingdom"...  1108561013    143.0
# 31    [{"iso_3166_1": "CN", "name": "China"}, {"iso_...  1215439994    130.0
# 32    [{"iso_3166_1": "US", "name": "United States o...  1025491110    108.0
# 33    [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   459359555    104.0
# 35    [{"iso_3166_1": "US", "name": "United States o...   836297228    150.0
# 36    [{"iso_3166_1": "US", "name": "United States o...  1091405097    165.0
# 37    [{"iso_3166_1": "US", "name": "United States o...   491868548    130.0
# 42    [{"iso_3166_1": "US", "name": "United States o...  1066969703    103.0
# 44    [{"iso_3166_1": "JP", "name": "Japan"}, {"iso_...  1506249360    137.0
# 45    [{"iso_3166_1": "US", "name": "United States o...   531865000    116.0
# 49    [{"iso_3166_1": "US", "name": "United States o...   351040419    143.0
# 52    [{"iso_3166_1": "US", "name": "United States o...  1123746996    154.0
# 54    [{"iso_3166_1": "US", "name": "United States o...   331926147     93.0
# 55    [{"iso_3166_1": "US", "name": "United States o...   538983207     93.0
# 61    [{"iso_3166_1": "US", "name": "United States o...   183987723    124.0
# 63    [{"iso_3166_1": "GB", "name": "United Kingdom"...   748806957    143.0
# 64    [{"iso_3166_1": "US", "name": "United States o...   543934787    144.0
# ...                                                 ...         ...      ...
# 4454  [{"iso_3166_1": "US", "name": "United States o...           0     88.0
# 4455  [{"iso_3166_1": "US", "name": "United States o...     1001437    114.0
# 4470  [{"iso_3166_1": "US", "name": "United States o...     4007792     85.0
# 4472   [{"iso_3166_1": "GB", "name": "United Kingdom"}]      171760     95.0
# 4473  [{"iso_3166_1": "US", "name": "United States o...       78396    102.0
# 4485  [{"iso_3166_1": "US", "name": "United States o...     4911725    107.0
# 4516  [{"iso_3166_1": "US", "name": "United States o...    17000000     97.0
# 4518  [{"iso_3166_1": "US", "name": "United States o...     8679814     88.0
# 4533  [{"iso_3166_1": "US", "name": "United States o...      343341     90.0
# 4539  [{"iso_3166_1": "FR", "name": "France"}, {"iso...       98017     85.0
# 4576  [{"iso_3166_1": "US", "name": "United States o...      258384     90.0
# 4586  [{"iso_3166_1": "US", "name": "United States o...   170000000     99.0
# 4604  [{"iso_3166_1": "US", "name": "United States o...     4500000    105.0
# 4609           [{"iso_3166_1": "FR", "name": "France"}]           0     91.0
# 4610  [{"iso_3166_1": "US", "name": "United States o...           0     81.0
# 4613  [{"iso_3166_1": "US", "name": "United States o...           0     80.0
# 4616  [{"iso_3166_1": "CM", "name": "Cameroon"}, {"i...           0    104.0
# 4630  [{"iso_3166_1": "US", "name": "United States o...      319285     90.0
# 4631  [{"iso_3166_1": "US", "name": "United States o...    12021272    113.0
# 4632  [{"iso_3166_1": "US", "name": "United States o...     4186931     91.0
# 4635  [{"iso_3166_1": "US", "name": "United States o...           0     94.0
# 4639           [{"iso_3166_1": "CA", "name": "Canada"}]      501818     90.0
# 4640        [{"iso_3166_1": "AU", "name": "Australia"}]           0     78.0
# 4643  [{"iso_3166_1": "US", "name": "United States o...     3542353     90.0
# 4650   [{"iso_3166_1": "GB", "name": "United Kingdom"}]           0    101.0
# 4700  [{"iso_3166_1": "US", "name": "United States o...     1776935     92.0
# 4715  [{"iso_3166_1": "US", "name": "United States o...           0     85.0
# 4717  [{"iso_3166_1": "US", "name": "United States o...     3200000     90.0
# 4744  [{"iso_3166_1": "US", "name": "United States o...           0     82.0
# 4752  [{"iso_3166_1": "US", "name": "United States o...      416498     99.0
#
#       vote_average  bechdel
# 1              6.9      1.0
# 4              6.1      1.0
# 6              7.4      1.0
# 7              7.3      1.0
# 8              7.4      1.0
# 14             6.5      1.0
# 15             6.3      1.0
# 21             6.2      1.0
# 22             7.6      1.0
# 23             5.8      1.0
# 25             7.5      1.0
# 26             7.1      1.0
# 28             6.5      1.0
# 29             6.9      1.0
# 31             6.8      1.0
# 32             6.4      1.0
# 33             6.3      1.0
# 35             6.0      1.0
# 36             5.8      1.0
# 37             5.7      1.0
# 42             7.6      1.0
# 44             7.3      1.0
# 45             6.7      1.0
# 49             7.3      1.0
# 52             6.1      1.0
# 54             6.6      1.0
# 55             6.7      1.0
# 61             5.2      1.0
# 63             6.7      1.0
# 64             6.4      1.0
# ...            ...      ...
# 4454           6.9      1.0
# 4455           5.6      1.0
# 4470           6.8      1.0
# 4472           6.0      1.0
# 4473           5.4      1.0
# 4485           6.5      1.0
# 4516           5.7      1.0
# 4518           7.4      1.0
# 4533           6.0      1.0
# 4539           5.7      1.0
# 4576           6.9      1.0
# 4586           5.8      1.0
# 4604           7.7      1.0
# 4609           6.1      1.0
# 4610           6.4      1.0
# 4613           6.4      1.0
# 4616           7.3      1.0
# 4630           6.3      1.0
# 4631           6.7      1.0
# 4632           6.3      1.0
# 4635           5.7      1.0
# 4639           6.9      1.0
# 4640           5.8      1.0
# 4643           6.4      1.0
# 4650           6.6      1.0
# 4700           6.8      1.0
# 4715           6.3      1.0
# 4717           6.5      1.0
# 4744           5.2      1.0
# 4752           5.6      1.0
#
# [1358 rows x 11 columns]

# %%
with open('data/bechdel.pkl', 'wb') as f: 
    pickle.dump(movies_bechdel, f)
